# %%
import pandas as pd
df_bpi= pd.read_csv("BPI_Challenge_2017.csv")
df_bpi['time'] = pd.to_datetime(df_bpi['time'], errors='coerce')

# %%
# Function to create prefixes and compute total time of prefix in seconds
def make_prefixes(dftest):
    dftest['prefix'] = ''  # Initialize the 'prefix' column
    dftest['total_time'] = None  # Initialize the 'total_time' column

    # Group the DataFrame by case_id
    grouped = dftest.groupby('case')

    # Iterate through each case group
    for case_id, group in grouped:
        prefix_list = []  # Initialize an empty list to track prefixes
        first_time = None  # To track the first activity time
        for index, row in group.iterrows():
            # Append the current event to the prefix list
            prefix_list.append(row['event'])

            # Track the time of the first activity in the prefix
            if first_time is None:
                first_time = row['time']

            # Calculate the total time difference (current time - first activity time)
            total_time = (row['time'] - first_time).total_seconds()  # in seconds

            # Assign the updated prefix and total time to the respective columns
            dftest.at[index, 'prefix'] = prefix_list.copy()
            dftest.at[index, 'total_time'] = total_time

    # Ensure the prefix column contains lists
    dftest['prefix'] = dftest['prefix'].apply(lambda x: list(x))
    
    # Optional: Drop any rows if required
    dftest = dftest[:-1]
    return dftest

# Call the function
df = make_prefixes(df_bpi)

# Display the result
df
# Out:
#                            case                   event  \
# 0         Application_652823628    A_Create Application
# 1         Application_652823628             A_Submitted
# 2         Application_652823628          W_Handle leads
# 3         Application_652823628          W_Handle leads
# 4         Application_652823628  W_Complete application
# ...                         ...                     ...
# 1202261  Application_1350494635     W_Call after offers
# 1202262  Application_1350494635     W_Call after offers
# 1202263  Application_1350494635     W_Call after offers
# 1202264  Application_1350494635             A_Cancelled
# 1202265  Application_1350494635             O_Cancelled
#
#                            time lifecycle:transition ApplicationType  \
# 0       2016-01-01 10:51:15.304             COMPLETE      New credit
# 1       2016-01-01 10:51:15.352             COMPLETE      New credit
# 2       2016-01-01 10:51:15.774             SCHEDULE      New credit
# 3       2016-01-01 10:52:36.392             WITHDRAW      New credit
# 4       2016-01-01 10:52:36.403             SCHEDULE      New credit
# ...                         ...                  ...             ...
# 1202261 2017-01-02 20:29:25.989              SUSPEND      New credit
# 1202262 2017-01-06 07:33:02.212            ATE_ABORT      New credit
# 1202263 2017-01-06 07:33:02.221             SCHEDULE      New credit
# 1202264 2017-01-16 10:51:21.114             COMPLETE      New credit
# 1202265 2017-01-16 10:51:21.139             COMPLETE      New credit
#
#                        LoanGoal  RequestedAmount  MonthlyCost org:resource  \
# 0        Existing loan takeover          20000.0          NaN       User_1
# 1        Existing loan takeover          20000.0          NaN       User_1
# 2        Existing loan takeover          20000.0          NaN       User_1
# 3        Existing loan takeover          20000.0          NaN       User_1
# 4        Existing loan takeover          20000.0          NaN       User_1
# ...                         ...              ...          ...          ...
# 1202261        Home improvement          20000.0          NaN      User_96
# 1202262        Home improvement          20000.0          NaN       User_1
# 1202263        Home improvement          20000.0          NaN       User_1
# 1202264        Home improvement          20000.0          NaN      User_28
# 1202265        Home improvement          20000.0          NaN      User_28
#
#         Selected  ...           OfferID FirstWithdrawalAmount       Action  \
# 0            NaN  ...               NaN                   NaN      Created
# 1            NaN  ...               NaN                   NaN  statechange
# 2            NaN  ...               NaN                   NaN      Created
# 3            NaN  ...               NaN                   NaN      Deleted
# 4            NaN  ...               NaN                   NaN      Created
# ...          ...  ...               ...                   ...          ...
# 1202261      NaN  ...               NaN                   NaN     Released
# 1202262      NaN  ...               NaN                   NaN      Deleted
# 1202263      NaN  ...               NaN                   NaN      Created
# 1202264      NaN  ...               NaN                   NaN  statechange
# 1202265      NaN  ...  Offer_1580299144                   NaN  statechange
#
#         Accepted CreditScore  NumberOfTerms  EventOrigin OfferedAmount  \
# 0            NaN         NaN            NaN  Application           NaN
# 1            NaN         NaN            NaN  Application           NaN
# 2            NaN         NaN            NaN     Workflow           NaN
# 3            NaN         NaN            NaN     Workflow           NaN
# 4            NaN         NaN            NaN     Workflow           NaN
# ...          ...         ...            ...          ...           ...
# 1202261      NaN         NaN            NaN     Workflow           NaN
# 1202262      NaN         NaN            NaN     Workflow           NaN
# 1202263      NaN         NaN            NaN     Workflow           NaN
# 1202264      NaN         NaN            NaN  Application           NaN
# 1202265      NaN         NaN            NaN        Offer           NaN
#
#                                                     prefix   total_time
# 0                                   [A_Create Application]          0.0
# 1                      [A_Create Application, A_Submitted]        0.048
# 2        [A_Create Application, A_Submitted, W_Handle l...         0.47
# 3        [A_Create Application, A_Submitted, W_Handle l...       81.088
# 4        [A_Create Application, A_Submitted, W_Handle l...       81.099
# ...                                                    ...          ...
# 1202261  [A_Create Application, A_Submitted, W_Handle l...   165092.773
# 1202262  [A_Create Application, A_Submitted, W_Handle l...   464108.996
# 1202263  [A_Create Application, A_Submitted, W_Handle l...   464109.005
# 1202264  [A_Create Application, A_Submitted, W_Handle l...  1340007.898
# 1202265  [A_Create Application, A_Submitted, W_Handle l...  1340007.923
#
# [1202266 rows x 21 columns]

# %%
df['prefix_length'] = df['prefix'].apply(len) #compute prefix length
# Out:
# C:\Users\20203384\AppData\Local\Temp\ipykernel_26192\2091437613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prefix_length'] = df['prefix'].apply(len) #compute prefix length

# %%
case_traces = df.groupby('case')['event'].apply(list)

# Map the aggregated traces back to the original DataFrame
df['case_trace'] = df['case'].map(case_traces)
# Out:
# C:\Users\20203384\AppData\Local\Temp\ipykernel_26192\2615126301.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['case_trace'] = df['case'].map(case_traces)

# %%
df['A_Cancelled_in_prefix'] = df['prefix'].apply(lambda x: x.count('A_Cancelled')) #New column which checks if A_cancelled has happened in the prefix

df['A_Cancelled_occured'] = df['case_trace'].apply(lambda x: x.count('A_Cancelled')) #New col which checks if A_Cancelled has/will happen in the case
# Out:
# C:\Users\20203384\AppData\Local\Temp\ipykernel_26192\3324765761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A_Cancelled_in_prefix'] = df['prefix'].apply(lambda x: x.count('A_Cancelled'))
# C:\Users\20203384\AppData\Local\Temp\ipykernel_26192\3324765761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A_Cancelled_occured'] = df['case_trace'].apply(lambda x: x.count('A_Cancelled'))

# %%
df = df[(df['A_Cancelled_in_prefix'] != 1)] #Remove rows where A_Cancelled has already happened

# %%
# Create new columns which are index encodings 
def index_encoding(df_testje):

    df_testje.reset_index(inplace=True)
    max_length = df_testje['prefix'].apply(len).max()  # Find the longest prefix
    expanded_prefix = pd.DataFrame(df_testje['prefix'].tolist(), columns=[f'event_{i+1}' for i in range(max_length)])

    # Concatenate the original dataframe with the expanded prefixes
    #df_testje = pd.concat([df_testje, expanded_prefix], axis=1)
    expanded_prefix

    result = df_testje.join(expanded_prefix)
    result.drop('index', axis=1)
    return result

# %%
df = index_encoding(df)
df
# Out:
#            index                    case                   event  \
# 0              0   Application_652823628    A_Create Application
# 1              1   Application_652823628             A_Submitted
# 2              2   Application_652823628          W_Handle leads
# 3              3   Application_652823628          W_Handle leads
# 4              4   Application_652823628  W_Complete application
# ...          ...                     ...                     ...
# 1168381  1202259  Application_1350494635     W_Call after offers
# 1168382  1202260  Application_1350494635              A_Complete
# 1168383  1202261  Application_1350494635     W_Call after offers
# 1168384  1202262  Application_1350494635     W_Call after offers
# 1168385  1202263  Application_1350494635     W_Call after offers
#
#                            time lifecycle:transition ApplicationType  \
# 0       2016-01-01 10:51:15.304             COMPLETE      New credit
# 1       2016-01-01 10:51:15.352             COMPLETE      New credit
# 2       2016-01-01 10:51:15.774             SCHEDULE      New credit
# 3       2016-01-01 10:52:36.392             WITHDRAW      New credit
# 4       2016-01-01 10:52:36.403             SCHEDULE      New credit
# ...                         ...                  ...             ...
# 1168381 2017-01-02 20:27:20.472                START      New credit
# 1168382 2017-01-02 20:27:20.474             COMPLETE      New credit
# 1168383 2017-01-02 20:29:25.989              SUSPEND      New credit
# 1168384 2017-01-06 07:33:02.212            ATE_ABORT      New credit
# 1168385 2017-01-06 07:33:02.221             SCHEDULE      New credit
#
#                        LoanGoal  RequestedAmount  MonthlyCost org:resource  \
# 0        Existing loan takeover          20000.0          NaN       User_1
# 1        Existing loan takeover          20000.0          NaN       User_1
# 2        Existing loan takeover          20000.0          NaN       User_1
# 3        Existing loan takeover          20000.0          NaN       User_1
# 4        Existing loan takeover          20000.0          NaN       User_1
# ...                         ...              ...          ...          ...
# 1168381        Home improvement          20000.0          NaN      User_96
# 1168382        Home improvement          20000.0          NaN      User_96
# 1168383        Home improvement          20000.0          NaN      User_96
# 1168384        Home improvement          20000.0          NaN       User_1
# 1168385        Home improvement          20000.0          NaN       User_1
#
#          ... event_171 event_172 event_173  event_174 event_175 event_176  \
# 0        ...      None      None      None       None      None      None
# 1        ...      None      None      None       None      None      None
# 2        ...      None      None      None       None      None      None
# 3        ...      None      None      None       None      None      None
# 4        ...      None      None      None       None      None      None
# ...      ...       ...       ...       ...        ...       ...       ...
# 1168381  ...      None      None      None       None      None      None
# 1168382  ...      None      None      None       None      None      None
# 1168383  ...      None      None      None       None      None      None
# 1168384  ...      None      None      None       None      None      None
# 1168385  ...      None      None      None       None      None      None
#
#          event_177  event_178 event_179  event_180
# 0             None       None      None       None
# 1             None       None      None       None
# 2             None       None      None       None
# 3             None       None      None       None
# 4             None       None      None       None
# ...            ...        ...       ...        ...
# 1168381       None       None      None       None
# 1168382       None       None      None       None
# 1168383       None       None      None       None
# 1168384       None       None      None       None
# 1168385       None       None      None       None
#
# [1168386 rows x 206 columns]

# %%
df = df.drop('index', axis=1)

# %%
df_x.columns.to_list()
# Out:
# ['case',
#  'event',
#  'time',
#  'lifecycle:transition',
#  'ApplicationType',
#  'LoanGoal',
#  'RequestedAmount',
#  'MonthlyCost',
#  'org:resource',
#  'Selected',
#  'EventID',
#  'OfferID',
#  'FirstWithdrawalAmount',
#  'Action',
#  'Accepted',
#  'CreditScore',
#  'NumberOfTerms',
#  'EventOrigin',
#  'OfferedAmount',
#  'prefix',
#  'total_time',
#  'prefix_length',
#  'case_trace',
#  'A_Cancelled_in_prefix',
#  'A_Cancelled_occured',
#  'event_1',
#  'event_2',
#  'event_3',
#  'event_4',
#  'event_5',
#  'event_6',
#  'event_7',
#  'event_8',
#  'event_9',
#  'event_10',
#  'event_11',
#  'event_12',
#  'event_13',
#  'event_14',
#  'event_15',
#  'event_16',
#  'event_17',
#  'event_18',
#  'event_19',
#  'event_20',
#  'event_21',
#  'event_22',
#  'event_23',
#  'event_24',
#  'event_25',
#  'event_26',
#  'event_27',
#  'event_28',
#  'event_29',
#  'event_30',
#  'event_31',
#  'event_32',
#  'event_33',
#  'event_34',
#  'event_35',
#  'event_36',
#  'event_37',
#  'event_38',
#  'event_39',
#  'event_40',
#  'event_41',
#  'event_42',
#  'event_43',
#  'event_44',
#  'event_45',
#  'event_46',
#  'event_47',
#  'event_48',
#  'event_49',
#  'event_50',
#  'event_51',
#  'event_52',
#  'event_53',
#  'event_54',
#  'event_55',
#  'event_56',
#  'event_57',
#  'event_58',
#  'event_59',
#  'event_60',
#  'event_61',
#  'event_62',
#  'event_63',
#  'event_64',
#  'event_65',
#  'event_66',
#  'event_67',
#  'event_68',
#  'event_69',
#  'event_70',
#  'event_71',
#  'event_72',
#  'event_73',
#  'event_74',
#  'event_75',
#  'event_76',
#  'event_77',
#  'event_78',
#  'event_79',
#  'event_80',
#  'event_81',
#  'event_82',
#  'event_83',
#  'event_84',
#  'event_85',
#  'event_86',
#  'event_87',
#  'event_88',
#  'event_89',
#  'event_90',
#  'event_91',
#  'event_92',
#  'event_93',
#  'event_94',
#  'event_95',
#  'event_96',
#  'event_97',
#  'event_98',
#  'event_99',
#  'event_100',
#  'event_101',
#  'event_102',
#  'event_103',
#  'event_104',
#  'event_105',
#  'event_106',
#  'event_107',
#  'event_108',
#  'event_109',
#  'event_110',
#  'event_111',
#  'event_112',
#  'event_113',
#  'event_114',
#  'event_115',
#  'event_116',
#  'event_117',
#  'event_118',
#  'event_119',
#  'event_120',
#  'event_121',
#  'event_122',
#  'event_123',
#  'event_124',
#  'event_125',
#  'event_126',
#  'event_127',
#  'event_128',
#  'event_129',
#  'event_130',
#  'event_131',
#  'event_132',
#  'event_133',
#  'event_134',
#  'event_135',
#  'event_136',
#  'event_137',
#  'event_138',
#  'event_139',
#  'event_140',
#  'event_141',
#  'event_142',
#  'event_143',
#  'event_144',
#  'event_145',
#  'event_146',
#  'event_147',
#  'event_148',
#  'event_149',
#  'event_150',
#  'event_151',
#  'event_152',
#  'event_153',
#  'event_154',
#  'event_155',
#  'event_156',
#  'event_157',
#  'event_158',
#  'event_159',
#  'event_160',
#  'event_161',
#  'event_162',
#  'event_163',
#  'event_164',
#  'event_165',
#  'event_166',
#  'event_167',
#  'event_168',
#  'event_169',
#  'event_170',
#  'event_171',
#  'event_172',
#  'event_173',
#  'event_174',
#  'event_175',
#  'event_176',
#  'event_177',
#  'event_178',
#  'event_179',
#  'event_180']

# %%
df_x.isnull().sum(axis=0) #Check for Nan values in columns
# Out:
# lifecycle:transition          0
# ApplicationType               0
# LoanGoal                      0
# RequestedAmount               0
# org:resource                  0
#                          ...
# event_176               1168376
# event_177               1168378
# event_178               1168380
# event_179               1168382
# event_180               1168384
# Length: 193, dtype: int64

# %%
df_x = df.copy()
remove_these_cols = ['case', 'event', 'time', 'MonthlyCost', 'Selected', 'OfferID', 
                     'FirstWithdrawalAmount', 'Accepted', 'CreditScore', 'NumberOfTerms', 
                     'OfferedAmount','A_Cancelled_occured']
df_x = df_x.drop(remove_these_cols, axis=1)
df_y = df[['A_Cancelled_occured']]
df_y.replace({0: False, 1:True}, inplace=True)
# Out:
# C:\Users\20203384\AppData\Local\Temp\ipykernel_26192\3034709633.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y.replace({0: False, 1:True}, inplace=True)

# %%
df_y
# Out:
#          A_Cancelled_occured
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 1168381                 True
# 1168382                 True
# 1168383                 True
# 1168384                 True
# 1168385                 True
#
# [1168386 rows x 1 columns]

# %%
df_x
# Out:
#         lifecycle:transition ApplicationType                LoanGoal  \
# 0                   COMPLETE      New credit  Existing loan takeover
# 1                   COMPLETE      New credit  Existing loan takeover
# 2                   SCHEDULE      New credit  Existing loan takeover
# 3                   WITHDRAW      New credit  Existing loan takeover
# 4                   SCHEDULE      New credit  Existing loan takeover
# ...                      ...             ...                     ...
# 1168381                START      New credit        Home improvement
# 1168382             COMPLETE      New credit        Home improvement
# 1168383              SUSPEND      New credit        Home improvement
# 1168384            ATE_ABORT      New credit        Home improvement
# 1168385             SCHEDULE      New credit        Home improvement
#
#          RequestedAmount org:resource                EventID       Action  \
# 0                20000.0       User_1  Application_652823628      Created
# 1                20000.0       User_1   ApplState_1582051990  statechange
# 2                20000.0       User_1    Workitem_1298499574      Created
# 3                20000.0       User_1    Workitem_1673366067      Deleted
# 4                20000.0       User_1    Workitem_1493664571      Created
# ...                  ...          ...                    ...          ...
# 1168381          20000.0      User_96     Workitem_358206591     Obtained
# 1168382          20000.0      User_96   ApplState_1120616436  statechange
# 1168383          20000.0      User_96     Workitem_146325658     Released
# 1168384          20000.0       User_1    Workitem_1817549786      Deleted
# 1168385          20000.0       User_1     Workitem_363876066      Created
#
#          EventOrigin                                             prefix  \
# 0        Application                             [A_Create Application]
# 1        Application                [A_Create Application, A_Submitted]
# 2           Workflow  [A_Create Application, A_Submitted, W_Handle l...
# 3           Workflow  [A_Create Application, A_Submitted, W_Handle l...
# 4           Workflow  [A_Create Application, A_Submitted, W_Handle l...
# ...              ...                                                ...
# 1168381     Workflow  [A_Create Application, A_Submitted, W_Handle l...
# 1168382  Application  [A_Create Application, A_Submitted, W_Handle l...
# 1168383     Workflow  [A_Create Application, A_Submitted, W_Handle l...
# 1168384     Workflow  [A_Create Application, A_Submitted, W_Handle l...
# 1168385     Workflow  [A_Create Application, A_Submitted, W_Handle l...
#
#          total_time  ...  event_171 event_172  event_173 event_174 event_175  \
# 0               0.0  ...       None      None       None      None      None
# 1             0.048  ...       None      None       None      None      None
# 2              0.47  ...       None      None       None      None      None
# 3            81.088  ...       None      None       None      None      None
# 4            81.099  ...       None      None       None      None      None
# ...             ...  ...        ...       ...        ...       ...       ...
# 1168381  164967.256  ...       None      None       None      None      None
# 1168382  164967.258  ...       None      None       None      None      None
# 1168383  165092.773  ...       None      None       None      None      None
# 1168384  464108.996  ...       None      None       None      None      None
# 1168385  464109.005  ...       None      None       None      None      None
#
#         event_176 event_177 event_178 event_179 event_180
# 0            None      None      None      None      None
# 1            None      None      None      None      None
# 2            None      None      None      None      None
# 3            None      None      None      None      None
# 4            None      None      None      None      None
# ...           ...       ...       ...       ...       ...
# 1168381      None      None      None      None      None
# 1168382      None      None      None      None      None
# 1168383      None      None      None      None      None
# 1168384      None      None      None      None      None
# 1168385      None      None      None      None      None
#
# [1168386 rows x 193 columns]
